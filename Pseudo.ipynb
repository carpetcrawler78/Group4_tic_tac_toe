# %% [markdown]
# INPUT: indicates a user will be inputting something
# OUTPUT: indicates that an output will appear on the screen
# WHILE: a loop (iteration that has a condition at the beginning)
# FOR: a counting loop (iteration)
# REPEAT – UNTIL: a loop (iteration) that has a condition at the end
# IF – THEN – ELSE: a decision (selection) in which a choice is made
# any instructions that occur inside a selection or iteration are usually indented

# %% [markdown]
# REPEAT
#     OUTPUT 'Player 1 which row'
#     INPUT user inputs row nr
#     OUTPUT 'which colum?'
#     INPUT user inputs row nr
#     IF field valid THEN
#         OUTPUT field = Symbol
#         CHECK if win / board full
#     ELSE
#         OUTPUT 'Field is not possible'
# UNTIL Board full
# OR one Row if full

# %% [markdown]
# Class board
# board= [[' ',' ',' '],[' ',' ',' '],[' ',' ',' ']]
#
# rundenzahl: int
# game: true
# next: int
#
#
#
# def input
#    While game = true
#    input()
#     - welche reihe row:
#     - if row <2
#     - welches Spalte colum:
#     - if colum <2
#     - evaluation ob feld erlaubt
#       - if board[row][colum]==0
#       - row colum
#     - ruft has_won auf
#
#
# def has_won
#     - for every list in board
#     - for every element IF list == X or == O
#     - all()
#     - if board[0][0] == board[1][0] == board[2][0]
#     - if board[0][0] ==  board[1][0] == board[2][0]
#     - if geht noch ein zug?
#     - rundenzahl ++
#     - else ruft input auf

# %%
class board: 

    def __init__(self):
        self.board = [[' ',' ',' '],[' ',' ',' '],[' ',' ',' ']]
        self.player='O'
        print("board gibts")
        self.eingabe()


    def eingabe(self):
        if self.player == 'x':
            self.player = 'x'
        else:
            self.player = 'x'

        row: int
        colum : int
        row = int(input('gib mal zeile ein'))
        print(f'row = {row}')
        colum = int(input('gib mal spalte ein'))
        print(f'colum = {colum}')
        self.board[row][colum]=self.player
        print(self.board)
        self.check()
        pass


    def check(self):
        ## Rows

        if all(cell == self.player for cell in self.board[0]):
            print('gewonnen in reihe 0')

        if all(cell == self.player for cell in self.board[1]):
            print('gewonnen in reihe 1')

        if all(cell == self.player for cell in self.board[2]):
            print('gewonnen in reihe 2')



    ## colums
        if self.board[0][0] == self.board[1][0] == self.board[2][0] == self.player:
            print ('Reihe links ist voll')
        
        if self.board[0][1] == self.board[1][1] == self.board[2][1] == self.player:
            print ('Reihe links ist voll')

        if self.board[0][2] == self.board[1][2] == self.board[2][2] == self.player:
            print ('Reihe links ist voll')
        self.eingabe()
        
        
        pass
        

board = board()
# Out:
# board gibts
# row = 0
# colum = 0
# [['x', ' ', ' '], [' ', ' ', ' '], [' ', ' ', ' ']]
# row = 1
# colum = 0
# [['x', ' ', ' '], ['x', ' ', ' '], [' ', ' ', ' ']]
# row = 2
# colum = 0
# [['x', ' ', ' '], ['x', ' ', ' '], ['x', ' ', ' ']]
# Reihe links ist voll
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 53
#      49         self.eingabe()
#      50         pass
# ---> 53 board = board()
#
# Cell In[44], line 7, in board.__init__(self)
#       5 self.player='O'
#       6 print("board gibts")
# ----> 7 self.eingabe()
#
# Cell In[44], line 23, in board.eingabe(self)
#      21 self.board[row][colum]=self.player
#      22 print(self.board)
# ---> 23 self.check()
#      24 pass
#
# Cell In[44], line 49, in board.check(self)
#      47 if self.board[0][2] == self.board[1][2] == self.board[2][2] == self.player:
#      48     print ('Reihe links ist voll')
# ...
